# %%
import spacy

# %% [markdown]
# ## Load Model

# %%
nlp_id = spacy.blank('id')

# %%
nlp_en = spacy.load('en_core_web_sm')

# %%
text_id = """Jakarta, Maret 1998
Di sebuah senja, di sebuah rumah susun di Jakarta, mahasiswa bernama Biru Laut disergap empat lelaki tak dikenal. Bersama kawan-kawannya, Daniel Tumbuan, Sunu Dyantoro, Alex Perazon, dia dibawa ke sebuah tempat yang tak dikenal. Berbulan-bulan mereka disekap, diinterogasi, dipukul, ditendang, digantung, dan disetrum agar bersedia menjawab satu pertanyaan penting: siapakah yang berdiri di balik gerakan aktivis dan mahasiswa saat itu.
Jakarta, Juni 1998
Keluarga Arya Wibisono, seperti biasa, pada hari Minggu sore memasak bersama, menyediakan makanan kesukaan Biru Laut. Sang ayah akan meletakkan satu piring untuk dirinya, satu piring untuk sang ibu, satu piring untuk Biru Laut, dan satu piring untuk si bungsu Asmara Jati. Mereka duduk menanti dan menanti. Tapi Biru Laut tak kunjung muncul.
Jakarta, 2000
Asmara Jati, adik Biru Laut, beserta Tim Komisi Orang Hilang yang dipimpin Aswin Pradana mencoba mencari jejak mereka yang hilang serta merekam dan mempelajari testimoni mereka yang kembali. Anjani, kekasih Laut, para orangtua dan istri aktivis yang hilang menuntut kejelasan tentang anggota keluarga mereka. Sementara Biru Laut, dari dasar laut yang sunyi bercerita kepada kita, kepada dunia tentang apa yang terjadi pada dirinya dan kawan-kawannya.
Laut Bercerita, novel terbaru Leila S. Chudori, bertutur tentang kisah keluarga yang kehilangan, sekumpulan sahabat yang merasakan kekosongan di dada, sekelompok orang yang gemar menyiksa dan lancar berkhianat, sejumlah keluarga yang mencari kejelasan akan anaknya, dan tentang cinta yang tak akan luntur."""

# %%
text_en = """Toru, a quiet and preternaturally serious young college student in Tokyo, is devoted to Naoko, a beautiful and introspective young woman, but their mutual passion is marked by the tragic death of their best friend years before. Toru begins to adapt to campus life and the loneliness and isolation he faces there, but Naoko finds the pressures and responsibilities of life unbearable. As she retreats further into her own world, Toru finds himself reaching out to others and drawn to a fiercely independent and sexually liberated young woman.
A magnificent blending of the music, the mood, and the ethos that was the sixties with the story of one college student's romantic coming of age, Norwegian Wood brilliantly recaptures a young man's first, hopeless, and heroic love."""

# %% [markdown]
# ### Tokenizer

# %%
# using loaded module will made text into tokens
token_id = nlp_id(text_id)
print(type(token_id))
print(type(token_id[0]))
# Out:
# <class 'spacy.tokens.doc.Doc'>
# <class 'spacy.tokens.token.Token'>

# %%
for i, token in enumerate(token_id):
    print(f"token-{i}: {token}")
# Out:
# token-0: Jakarta
# token-1: ,
# token-2: Maret
# token-3: 1998
# token-4:
#
# token-5: Di
# token-6: sebuah
# token-7: senja
# token-8: ,
# token-9: di
# token-10: sebuah
# token-11: rumah
# token-12: susun
# token-13: di
# token-14: Jakarta
# token-15: ,
# token-16: mahasiswa
# token-17: bernama
# token-18: Biru
# token-19: Laut
# token-20: disergap
# token-21: empat
# token-22: lelaki
# token-23: tak
# token-24: dikenal
# token-25: .
# token-26: Bersama
# token-27: kawan
# token-28: -
# token-29: kawannya
# token-30: ,
# token-31: Daniel
# token-32: Tumbuan
# token-33: ,
# token-34: Sunu
# token-35: Dyantoro
# token-36: ,
# token-37: Alex
# token-38: Perazon
# token-39: ,
# token-40: dia
# token-41: dibawa
# token-42: ke
# token-43: sebuah
# token-44: tempat
# token-45: yang
# token-46: tak
# token-47: dikenal
# token-48: .
# token-49: Berbulan-bulan
# token-50: mereka
# token-51: disekap
# token-52: ,
# token-53: diinterogasi
# token-54: ,
# token-55: dipukul
# token-56: ,
# ...

# %%
token_en = nlp_en(text_en)
print(type(token_en))
print(type(token_en[0]))
# Out:
# <class 'spacy.tokens.doc.Doc'>
# <class 'spacy.tokens.token.Token'>

# %%
for i, token in enumerate(token_en):
    print(f"token-{i}: {token}")
# Out:
# token-0: Toru
# token-1: ,
# token-2: a
# token-3: quiet
# token-4: and
# token-5: preternaturally
# token-6: serious
# token-7: young
# token-8: college
# token-9: student
# token-10: in
# token-11: Tokyo
# token-12: ,
# token-13: is
# token-14: devoted
# token-15: to
# token-16: Naoko
# token-17: ,
# token-18: a
# token-19: beautiful
# token-20: and
# token-21: introspective
# token-22: young
# token-23: woman
# token-24: ,
# token-25: but
# token-26: their
# token-27: mutual
# token-28: passion
# token-29: is
# token-30: marked
# token-31: by
# token-32: the
# token-33: tragic
# token-34: death
# token-35: of
# token-36: their
# token-37: best
# token-38: friend
# token-39: years
# token-40: before
# token-41: .
# token-42: Toru
# token-43: begins
# token-44: to
# token-45: adapt
# token-46: to
# token-47: campus
# token-48: life
# token-49: and
# token-50: the
# token-51: loneliness
# token-52: and
# token-53: isolation
# token-54: he
# token-55: faces
# token-56: there
# ...

# %% [markdown]
# ### Sentence Splitter
# Only English modules is supported.

# %%
# .sents function join the token into sentence
for sent in token_en.sents:
    print(sent)
# Out:
# Toru, a quiet and preternaturally serious young college student in Tokyo, is devoted to Naoko, a beautiful and introspective young woman, but their mutual passion is marked by the tragic death of their best friend years before.
# Toru begins to adapt to campus life and the loneliness and isolation he faces there, but Naoko finds the pressures and responsibilities of life unbearable.
# As she retreats further into her own world, Toru finds himself reaching out to others and drawn to a fiercely independent and sexually liberated young woman.
#
# A magnificent blending of the music, the mood, and the ethos that was the sixties with the story of one college student's romantic coming of age, Norwegian Wood brilliantly recaptures a young man's first, hopeless, and heroic love.

# %% [markdown]
# ### Lemmatization

# %%
for token in token_en:
    ori = token.text
    lemma = token.lemma_ # _lemma is int index
    if (not token.is_stop and not token.is_punct and str(ori) != str(lemma)):
        print(f"{ori}: {lemma}")
# Out:
# devoted: devote
# marked: mark
# best: good
# years: year
# begins: begin
# faces: face
# finds: find
# pressures: pressure
# responsibilities: responsibility
# retreats: retreat
# finds: find
# reaching: reach
# drawn: draw
# sixties: sixty
# recaptures: recapture

# %% [markdown]
# ### Stemming
# Unfortunatlly, stemming is not supported in spaCy.

# %% [markdown]
# ### Entity Masking
# Apparently, the text that I used contain name of japanese people. So, the entity masking is not working properly in this case.

# %%
# check for the entity type
ner_en = nlp_en(text_en)

for token in ner_en:
    if (token.ent_type_ != ""):
        print(f"{token}: {token.ent_type_}")
# Out:
# Tokyo: GPE
# Naoko: ORG
# years: DATE
# Naoko: PERSON
# Toru: GPE
# the: DATE
# sixties: DATE
# one: CARDINAL
# Norwegian: ORG
# Wood: ORG
# first: ORDINAL

# %%
def replace_name(token):
    # check for the IOB tagging and entity type
    if (token.ent_type_ == "PERSON"):
        return "[PERSON] "
    return token.text_with_ws

masked = map(replace_name, ner_en)
print("".join(masked))
# Out:
# Toru, a quiet and preternaturally serious young college student in Tokyo, is devoted to Naoko, a beautiful and introspective young woman, but their mutual passion is marked by the tragic death of their best friend years before. Toru begins to adapt to campus life and the loneliness and isolation he faces there, but [PERSON] finds the pressures and responsibilities of life unbearable. As she retreats further into her own world, Toru finds himself reaching out to others and drawn to a fiercely independent and sexually liberated young woman.
# A magnificent blending of the music, the mood, and the ethos that was the sixties with the story of one college student's romantic coming of age, Norwegian Wood brilliantly recaptures a young man's first, hopeless, and heroic love.

# %% [markdown]
# Lets try another text.

# %%
another_text = "A merry little surge of electricity piped by automatic alarm from the mood organ beside his bed awakened Rick Deckard. ­Surprised—it always surprised him to find himself awake without prior notice—­he rose from the bed, stood up in his multicolored pajamas, and stretched. Now, in her bed, his wife Iran opened her gray, unmerry eyes, blinked, then groaned and shut her eyes again."
another_ner = nlp_en(another_text)

another_masked = map(replace_name, another_ner)
print("".join(another_masked))
# Out:
# A merry little surge of electricity piped by automatic alarm from the mood organ beside his bed awakened [PERSON] [PERSON] . ­Surprised—it always surprised him to find himself awake without prior notice—­he rose from the bed, stood up in his multicolored pajamas, and stretched. Now, in her bed, his wife Iran opened her gray, unmerry eyes, blinked, then groaned and shut her eyes again.

# %%
for token in another_ner:
    if (token.ent_type_ != ""):
        print(f"{token}: {token.ent_type_}")
# Out:
# Rick: PERSON
# Deckard: PERSON
# Iran: GPE

# %% [markdown]
# "Iran" in this case is actually a name, but the model is labeling it as a country.

# %% [markdown]
# ### POS Tagger

# %%
for token in token_en:
    if (not token.is_punct):
        # check for tagging and pos of each token
        print(f"TOKEN: {token}")
        print(f"TAG: {str(token.tag_):10}", end="\t")
        print(f"EXPLANATION: {spacy.explain(token.tag_)}")
        print(f"POS: {str(token.pos_):10}", end="\t")
        print(f"EXPLANATION: {spacy.explain(token.pos_)}")
        print("======")
# Out:
# TOKEN: Toru
# TAG: NNP       	EXPLANATION: noun, proper singular
# POS: PROPN     	EXPLANATION: proper noun
# ...
# TOKEN: a
# TAG: DT        	EXPLANATION: determiner
# POS: DET       	EXPLANATION: determiner
# ...
# TOKEN: quiet
# TAG: JJ        	EXPLANATION: adjective (English), other noun-modifier (Chinese)
# POS: ADJ       	EXPLANATION: adjective
# ...
# TOKEN: and
# TAG: CC        	EXPLANATION: conjunction, coordinating
# POS: CCONJ     	EXPLANATION: coordinating conjunction
# ...
# TOKEN: preternaturally
# TAG: RB        	EXPLANATION: adverb
# POS: ADV       	EXPLANATION: adverb
# ...
# TOKEN: serious
# TAG: JJ        	EXPLANATION: adjective (English), other noun-modifier (Chinese)
# POS: ADJ       	EXPLANATION: adjective
# ...
# TOKEN: young
# TAG: JJ        	EXPLANATION: adjective (English), other noun-modifier (Chinese)
# POS: ADJ       	EXPLANATION: adjective
# ...
# TOKEN: college
# TAG: NN        	EXPLANATION: noun, singular or mass
# POS: NOUN      	EXPLANATION: noun
# ...
# TOKEN: student
# ...

# %% [markdown]
# ### Phrase Chunking

# %%
for noun in token_en.noun_chunks:
    print(noun)
# Out:
# Toru
# a quiet and preternaturally serious young college student
# Tokyo
# Naoko
# a beautiful and introspective young woman
# their mutual passion
# the tragic death
# their best friend
# Toru
# campus life
# the loneliness
# isolation
# he
# Naoko
# the pressures
# responsibilities
# life
# she
# her own world
# Toru
# himself
# others
# a fiercely independent and sexually liberated young woman
# the music
# that
# the sixties
# the story
# one college student's romantic coming
# age
# Norwegian Wood
# a young man's first, hopeless, and heroic love
